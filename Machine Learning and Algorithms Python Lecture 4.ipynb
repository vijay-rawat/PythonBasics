# %%
#to find mean and standeard deviation through sklearn

# %%
import numpy as pd
from sklearn import preprocessing
input_data=np.array([[3,1.5,5,7],[5,5.5,6,7],[1,-3.5,7],[5,8,9,4]])
data_standardized=preprocessing.scale(input_data)
print("\nMean=",data_standardized.mean(axis=0))
print("Std Deviation=",data_standardized.std(axis=0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d46157cc1c9c> in <module>
#       2 from sklearn import preprocessing
#       3 input_data=np.array([[3,1.5,5,7],[5,5.5,6,7],[1,-3.5,7],[5,8,9,4]])
# ----> 4 data_standardized=preprocessing.scale(input_data)
#       5 print("\nMean=",data_standardized.mean(axis=0))
#       6 print("Std Deviation=",data_standardized.std(axis=0))
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     147     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     148                     warn_on_dtype=True, estimator='the scale function',
# --> 149                     dtype=FLOAT_DTYPES, force_all_finite='allow-nan')
#     150     if sparse.issparse(X):
#     151         if with_mean:
#
# ...

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
data_set=pd.read_csv('C:\\Users\\Vijay\\Downloads\\oyorooms.csv')
y=data_set.head(50)
x=pd.DataFrame(y["OLD PRICE"])
z=pd.DataFrame(y["PRICE AFTER DISCOUNT"])
data=np.array(y)
print(x,z)
x=dataset.iloc(:,:-1).values
y=dataset.iloc(:,1).values

from sklearn.module_selection_import_train_test_split
(strain,stest,ytrain,ytest
train_test_split(x,y,test.size=0.2)
random_state=0)

from sklearn import linear_model
alg=linear_model.LinearRegresson
alg.fut(xtrain,ytrain)

ypred=alg.predict(stest)

plt.scatter(xtest,ytest,'g')
plt.plot(xtest,alg.predict(xtest),'r')
plt.title('test')
plt.xlabel("Experience")
plt.ylabel("salary")
plt.show()

accuracy=alg.score(xtest,ytest)
print(accuracy)
# Out:
#    OLD PRICE
# 0     ₹ 2649
# 1     ₹ 3149
# 2     ₹ 1799
# 3     ₹ 1999
# 4     ₹ 3899
# 5     ₹ 1799
# 6     ₹ 6099
# 7     ₹ 1799
# 8     ₹ 1664
# 9     ₹ 4849
# 10    ₹ 1699
# 11    ₹ 1664
# 12    ₹ 3699
# 13    ₹ 3149
# 14    ₹ 4299
# 15    ₹ 3799
# 16    ₹ 4649
# 17    ₹ 2499
# 18    ₹ 3749
# 19    ₹ 3249
# 20    ₹ 4749
# 21    ₹ 3549
# 22    ₹ 2499
# 23    ₹ 3449
# 24    ₹ 4799
# 25    ₹ 2499
# 26    ₹ 3499
# 27    ₹ 4299
# 28    ₹ 2899
# 29    ₹ 2149
# 30    ₹ 2199
# 31    ₹ 1849
# 32    ₹ 2549
# 33    ₹ 2449
# 34    ₹ 2049
# 35    ₹ 2049
# 36    ₹ 2499
# 37    ₹ 1699
# 38    ₹ 3099
# 39    ₹ 1999
# 40    ₹ 2249
# 41    ₹ 2499
# 42    ₹ 2649
# 43    ₹ 1899
# 44    ₹ 1199
# 45    ₹ 3549
# 46    ₹ 2749
# 47    ₹ 2549
# 48    ₹ 1599
# 49    ₹ 1249    PRICE AFTER DISCOUNT
# 0                ₹ 1987
# 1                ₹ 2362
# 2                ₹ 1349
# 3                ₹ 1499
# 4                ₹ 2924
# 5                ₹ 1349
# 6                ₹ 4574
# 7                ₹ 1349
# ...

# %%
y=dataset.iloc(:,1).values

from sklearn.module_selection_import_train_test_split
(strain,stest,ytrain,ytest
train_test_split(x,y,test.size=0.2)
random_state=0)

from sklearn import linear_model
alg=linear_model.LinearRegresson
alg.fut(xtrain,ytrain)

ypred=alg.predict(stest)

plt.scatter(xtest,ytest,'g')
plt.plot(xtest,alg.predict(xtest),'r')
plt.title('test')
plt.xlabel("Experience")
plt.ylabel("salary")
plt.show()

accuracy=alg.score(xtest,ytest)
print(accuracy)
# Out:
#   File "<ipython-input-17-43339444a254>", line 1
#     y=dataset.iloc(:,1).values
#                    ^
# SyntaxError: invalid syntax
